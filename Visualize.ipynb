# %%
from pkg.service import stockservice as ss
from pkg.repo import stockdata as sd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

# %%
df = ss.create_price_stat_dataframe("INMD","ZSCORE")
#df["Volume"] = df["Volume"]/10000
#df.shape
#plt.plot(df["Stat"][:])
df.head()
# Out:
#                          Close      Stat
# 2019-10-18 07:00:00  25.950001  0.660241
# 2019-10-21 07:00:00  27.570000  1.140419
# 2019-10-22 07:00:00  29.820000  1.890599
# 2019-10-23 07:00:00  30.809999  2.176736
# 2019-10-24 07:00:00  30.209999  1.874852

# %%
#plt.plot(df["Close"][100:])
plt.plot(df["Stat"][100:])
#plt.plot(df["Volume"])
#plt.plot(y)

# %%
plt.plot(df["Close"][100:])
